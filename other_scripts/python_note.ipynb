# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(28,8))
L=6574
N=18
x=np.arange(0,L,1)
print(x.shape)
y=(np.cos(2*np.pi*x*N/L) + 0.58 * N  )/L +0.00005* np.random.randn(L)
np.savetxt('mb',y)
print(np.sum(y))
plt.plot(x, y)
y=10+20*x
# Out:
# (6574,)
# 10.447864532491645

# %%
6574/365
# Out:
# 18.01095890410959

# %%
x.shape

# %%
np.mean()
# Out:
# 0.007105397842264036
